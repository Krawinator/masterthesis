# %% [markdown]
# ## Eda

# %%
# ===============================================================
#   EDA – Exploratory Data Analysis für Leistungsband-Projekt
# ===============================================================

from src.main import main
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# ===============================================================
# 1) Daten laden (raw + clean)
# ===============================================================

res = main(run_full_pipeline=False)

raw = res["raw"]
clean = res["clean"]

print("---- Überblick ----")
print("Nodes:", len(clean["measurements"]))
print("Beispiel-Node:", next(iter(clean["measurements"].keys())))
print("Keys im Datenobjekt:", list(clean.keys()))


# ===============================================================
# 2) Zeitachsenanalyse – Frequenz, Gaps, Duplikate
# ===============================================================

freq_summary = []
for nid, s in clean["measurements"].items():
    diffs = s.index.to_series().diff().value_counts()
    freq_summary.append({
        "node": nid,
        "unique_steps": list(diffs.index.astype(str)),
        "step_counts": list(diffs.values),
    })

df_freq = pd.DataFrame(freq_summary)
print("\n---- Frequenz-Analyse ----")
print(df_freq)


# --- Gap Analyse ---
gap_info = {}
for nid, s in clean["measurements"].items():
    expected = pd.date_range(s.index.min(), s.index.max(), freq="15min")
    missing = expected.difference(s.index)
    if len(missing) > 0:
        gap_info[nid] = missing

print("\n---- Gefundene Lücken ----")
print(gap_info if gap_info else "Keine Lücken gefunden.")


# ===============================================================
# 3) NaN-Analyse (vor/nach Cleaning)
# ===============================================================

nan_stats = []
for nid, s_raw in raw["measurements"].items():
    s_clean = clean["measurements"][nid]
    nan_stats.append({
        "node": nid,
        "raw_nans": s_raw.isna().sum(),
        "clean_nans": s_clean.isna().sum(),
        "len_raw": len(s_raw),
        "len_clean": len(s_clean),
    })

df_nan = pd.DataFrame(nan_stats).set_index("node")
print("\n---- NaN Analyse P_MW ----")
print(df_nan)


# --- Wetterdaten NaN Analyse ---
weather_cols = ["temperature_C", "wind_speed_mps", "solar_radiation_Wm2"]

w_stats = []
for nid, df_w_raw in raw["weather_hist"].items():
    df_w_clean = clean["weather_hist"][nid]
    entry = {"node": nid}
    for col in weather_cols:
        entry[f"raw_nan_{col}"] = df_w_raw[col].isna().sum()
        entry[f"clean_nan_{col}"] = df_w_clean[col].isna().sum()
    w_stats.append(entry)

df_w_nan = pd.DataFrame(w_stats).set_index("node")
print("\n---- NaN Analyse Wetter ----")
print(df_w_nan)


# ===============================================================
# 4) Derived Nodes prüfen
# ===============================================================

def check_field_sum(clean, node_id, derived_spec):
    terms = derived_spec["terms"]
    p_der = clean["measurements"][node_id]

    parts = []
    for t in terms:
        nid = t["node"]
        coeff = t["coeff"]
        if nid in clean["measurements"]:
            parts.append(coeff * clean["measurements"][nid])
        else:
            print(f"⚠ Basisnode {nid} fehlt!")
            return None

    p_rec = sum(parts)
    idx = p_der.index.intersection(p_rec.index)
    diff = p_der.loc[idx] - p_rec.loc[idx]

    print(f"→ Derived Node {node_id} – Max Fehler:", diff.abs().max())
    return diff


print("\n---- Derived Node Validierung ----")

for nid, row in raw["nodes"].iterrows():
    if isinstance(row.get("derived"), dict):
        print(f"\nPrüfe Derived Node: {nid}")
        diff = check_field_sum(clean, nid, row["derived"])


# ===============================================================
# 5) Statistische EDA – Min/Max, Trends, Verteilungen
# ===============================================================

stats = []
for nid, s in clean["measurements"].items():
    stats.append({
        "node": nid,
        "min": s.min(),
        "max": s.max(),
        "mean": s.mean(),
        "std": s.std(),
    })

df_stats = pd.DataFrame(stats).set_index("node")
print("\n---- Basisstatistiken P_MW ----")
print(df_stats)


# --- Beispielplot für einen Node ---
example_node = next(iter(clean["measurements"].keys()))
s = clean["measurements"][example_node]

plt.figure(figsize=(12, 4))
s["2024-01-01":"2024-01-07"].plot()
plt.title(f"P_MW – Woche 1/2024 – {example_node}")
plt.grid(True)
plt.show()


# --- Saisonalität / Monatsmittel ---
s_month = s.resample("ME").mean()

plt.figure(figsize=(10,4))
s_month.plot(kind="bar")
plt.title(f"Monatsmittel P_MW – {example_node}")
plt.grid(True)
plt.show()


# ===============================================================
# 6) Wetter-Korrelationen & Forecast-Basis
# ===============================================================

def get_panel(clean, node):
    p = clean["measurements"][node].rename("P_MW")
    w = clean["weather_hist"][node]
    return w.join(p, how="inner")

panel = get_panel(clean, example_node)

print("\n---- Korrelationen zwischen Wetter und P_MW ----")
print(panel.corr())


# ===============================================================
# 7) Sprung- / Jump-Analyse (Diffs & große Schritte)
# ===============================================================

jump_stats = []

for nid, s in clean["measurements"].items():
    # 1. Differenzen
    diff = s.diff()

    # 2. Threshold: z.B. 3 * Standardabweichung der Differenzen
    thr = 3 * diff.std()

    # 3. "große" Sprünge zählen
    big_jumps = (diff.abs() > thr).sum()

    jump_stats.append({
        "node": nid,
        "diff_std": diff.std(),
        "threshold": thr,
        "num_big_jumps": big_jumps,
    })

df_jumps = pd.DataFrame(jump_stats).set_index("node")

print("\n---- Sprung-Analyse P_MW (diff-basierte Jumps) ----")
print(df_jumps.sort_values("num_big_jumps", ascending=False))


# Beispielplot: Diffs für example_node
s_ex = clean["measurements"][example_node]
diff_ex = s_ex.diff()

plt.figure(figsize=(12, 4))
diff_ex["2024-01-01":"2024-01-07"].plot()
plt.axhline(3*diff_ex.std(), linestyle="--")
plt.axhline(-3*diff_ex.std(), linestyle="--")
plt.title(f"Diff P_MW – Woche 1/2024 – {example_node}")
plt.grid(True)
plt.show()


# ===============================================================
# 8) Tages- und Wochenmuster (Daily/Weekly Profiles)
# ===============================================================

# Tagesprofil (Ø über alle Tage)
s_ex = clean["measurements"][example_node].dropna()
df_ex = s_ex.to_frame(name="P_MW")
df_ex["hour"] = df_ex.index.hour
df_ex["weekday"] = df_ex.index.dayofweek  # 0=Mo ... 6=So

hour_profile = df_ex.groupby("hour")["P_MW"].mean()
weekday_profile = df_ex.groupby("weekday")["P_MW"].mean()

print("\n---- Tagesprofil (P_MW, Mittelwert je Stunde) ----")
print(hour_profile)

print("\n---- Wochenprofil (P_MW, Mittelwert je Wochentag; 0=Mo) ----")
print(weekday_profile)

plt.figure(figsize=(10, 4))
hour_profile.plot(marker="o")
plt.title(f"Tagesprofil P_MW – {example_node}")
plt.xlabel("Stunde")
plt.ylabel("P_MW")
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 4))
weekday_profile.plot(kind="bar")
plt.title(f"Wochentagsprofil P_MW – {example_node}")
plt.xlabel("Wochentag (0=Mo)")
plt.ylabel("P_MW")
plt.grid(True)
plt.show()


# Optional: Wetter-Tagesprofil (z.B. Solarstrahlung)
if example_node in clean["weather_hist"]:
    w_ex = clean["weather_hist"][example_node].copy()
    w_ex["hour"] = w_ex.index.hour
    solar_hour_profile = w_ex.groupby("hour")["solar_radiation_Wm2"].mean()

    plt.figure(figsize=(10, 4))
    solar_hour_profile.plot(marker="o")
    plt.title(f"Tagesprofil Solarstrahlung – {example_node}")
    plt.xlabel("Stunde")
    plt.ylabel("W/m²")
    plt.grid(True)
    plt.show()


# ===============================================================
# 9) Korrelationen zwischen Nodes (P_MW vs P_MW)
# ===============================================================

# Panel aller Nodes: gemeinsame Zeitachse
df_all_p = pd.DataFrame({
    nid: s for nid, s in clean["measurements"].items()
})

corr_nodes = df_all_p.corr()

print("\n---- Korrelation P_MW zwischen Nodes ----")
print(corr_nodes)

plt.figure(figsize=(8, 6))
plt.imshow(corr_nodes, interpolation="nearest")
plt.colorbar(label="Korrelationskoeffizient")
plt.xticks(range(len(corr_nodes.columns)), corr_nodes.columns, rotation=90)
plt.yticks(range(len(corr_nodes.index)), corr_nodes.index)
plt.title("Korrelationen P_MW zwischen Nodes")
plt.tight_layout()
plt.show()


# ===============================================================
# 10) Outlier-Analyse (z-Score basierend)
# ===============================================================

outlier_stats = []

Z_THRESHOLD = 4.0  # z.B. |z| > 4 als Outlier

for nid, s in clean["measurements"].items():
    mu = s.mean()
    sigma = s.std()

    if sigma == 0 or np.isnan(sigma):
        num_outliers = 0
    else:
        z = (s - mu) / sigma
        num_outliers = (z.abs() > Z_THRESHOLD).sum()

    outlier_stats.append({
        "node": nid,
        "mean": mu,
        "std": sigma,
        "num_outliers(|z|>4)": num_outliers,
        "outlier_fraction": num_outliers / len(s),
    })

df_outliers = pd.DataFrame(outlier_stats).set_index("node")

print("\n---- Outlier-Analyse P_MW (z-Score) ----")
print(df_outliers.sort_values("outlier_fraction", ascending=False))


# Beispiel: Outlier-Scatter für example_node
s_ex = clean["measurements"][example_node]
mu_ex = s_ex.mean()
sigma_ex = s_ex.std()
z_ex = (s_ex - mu_ex) / sigma_ex

outlier_mask = z_ex.abs() > Z_THRESHOLD

plt.figure(figsize=(12, 4))
plt.plot(s_ex.index, s_ex.values, label="P_MW")
plt.scatter(s_ex.index[outlier_mask], s_ex[outlier_mask], marker="x")
plt.title(f"Outlier-Check P_MW – {example_node} (|z|>{Z_THRESHOLD})")
plt.grid(True)
plt.show()

print("\nEDA erweitert um Sprünge, Tages-/Wochenprofile, Node-Korrelationen und Outlier.")

print("\nEDA abgeschlossen.")
# Out:
# 2025-12-17 12:00:17 [INFO] src.utils.logging_config - Logging initialisiert. Logfile: logs/service.log
# 2025-12-17 12:00:17 [INFO] src.main - Starte Leistungsband-Service...
# 2025-12-17 12:00:17 [INFO] src.data.data_loader - Starte Laden der historischen Wirkleistungs- und Wetterdaten (global_start_local=2024-01-01 01:00:00+01:00, end_local=2025-12-17 12:00:17.397424+01:00, global_start_utc=2024-01-01 00:00:00+00:00, end_time_utc=2025-12-17 11:00:17.397424+00:00) ...
# 2025-12-17 12:00:17 [INFO] src.data.data_loader - Lade Knotendaten (inkl. P_Datapoint_ID, Lat/Lon, DerivedSpec) aus /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/graph/whole_graph.json ...
# 2025-12-17 12:00:17 [INFO] src.data.data_loader - Knotendaten geladen: 16 Knoten.
# 2025-12-17 12:00:17 [INFO] src.data.data_loader - Verarbeite Node SHUW_E24 (DP=97f72ae3-8fe4-4ef6-a3f6-5f58b2ec2380) ...
# 2025-12-17 12:00:17 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für SHUW_E24: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:17 [INFO] src.data.data_loader - Node SHUW_E24: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:17 [INFO] src.data.eiot_client - EIOT: Hole Access-Token via Azure AD (Client Credentials).
# 2025-12-17 12:00:17 [INFO] src.data.eiot_client - EIOT: Access-Token erfolgreich erhalten.
# 2025-12-17 12:00:17 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=97f72ae3-8fe4-4ef6-a3f6-5f58b2ec2380, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:17 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=97f72ae3-8fe4-4ef6-a3f6-5f58b2ec2380 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:17 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=97f72ae3-8fe4-4ef6-a3f6-5f58b2ec2380 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:18 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.521858, lon=9.436780, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:18 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:23 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:23 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:23 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:23 [INFO] src.data.data_loader - Wetterdaten für Node SHUW_E24 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:23 [INFO] src.data.data_loader - Historische Zeitreihen für SHUW_E24 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/SHUW_E24_hist.csv
# 2025-12-17 12:00:23 [INFO] src.data.data_loader - Verarbeite Node SHUW_E23 (DP=bf20523d-4b54-44f3-800b-0a49cdc447aa) ...
# 2025-12-17 12:00:23 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für SHUW_E23: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:23 [INFO] src.data.data_loader - Node SHUW_E23: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:23 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=bf20523d-4b54-44f3-800b-0a49cdc447aa, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:23 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=bf20523d-4b54-44f3-800b-0a49cdc447aa -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:23 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=bf20523d-4b54-44f3-800b-0a49cdc447aa -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:23 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.521858, lon=9.436780, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:23 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:24 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:24 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:25 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:25 [INFO] src.data.data_loader - Wetterdaten für Node SHUW_E23 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:25 [INFO] src.data.data_loader - Historische Zeitreihen für SHUW_E23 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/SHUW_E23_hist.csv
# 2025-12-17 12:00:25 [INFO] src.data.data_loader - Node JUBO_E01 ist ein derived node – EIOT- und Wetter-Abruf werden später aus Basis-Knoten abgeleitet.
# 2025-12-17 12:00:25 [INFO] src.data.data_loader - Verarbeite Node JUBO_E02 (DP=dd4d7a23-431a-49a8-923d-8baa3f00d85d) ...
# 2025-12-17 12:00:25 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für JUBO_E02: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:25 [INFO] src.data.data_loader - Node JUBO_E02: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:25 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=dd4d7a23-431a-49a8-923d-8baa3f00d85d, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:25 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=dd4d7a23-431a-49a8-923d-8baa3f00d85d -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:25 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=dd4d7a23-431a-49a8-923d-8baa3f00d85d -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:25 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.546726, lon=9.428365, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:25 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:28 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:28 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:28 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:28 [INFO] src.data.data_loader - Wetterdaten für Node JUBO_E02 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:28 [INFO] src.data.data_loader - Historische Zeitreihen für JUBO_E02 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/JUBO_E02_hist.csv
# 2025-12-17 12:00:28 [INFO] src.data.data_loader - Verarbeite Node JUBO_E03 (DP=7b3fec1d-2c6f-4450-b41a-74d709e1c3b6) ...
# 2025-12-17 12:00:29 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für JUBO_E03: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:29 [INFO] src.data.data_loader - Node JUBO_E03: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:29 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=7b3fec1d-2c6f-4450-b41a-74d709e1c3b6, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:29 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=7b3fec1d-2c6f-4450-b41a-74d709e1c3b6 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:29 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=7b3fec1d-2c6f-4450-b41a-74d709e1c3b6 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:29 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.546726, lon=9.428365, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:29 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:30 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:30 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:30 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:30 [INFO] src.data.data_loader - Wetterdaten für Node JUBO_E03 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:30 [INFO] src.data.data_loader - Historische Zeitreihen für JUBO_E03 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/JUBO_E03_hist.csv
# 2025-12-17 12:00:30 [INFO] src.data.data_loader - Verarbeite Node TARP_E03 (DP=7ac182fc-cbfd-46c4-85bb-2a546cb238e1) ...
# 2025-12-17 12:00:30 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für TARP_E03: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:30 [INFO] src.data.data_loader - Node TARP_E03: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:30 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=7ac182fc-cbfd-46c4-85bb-2a546cb238e1, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:30 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=7ac182fc-cbfd-46c4-85bb-2a546cb238e1 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:30 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=7ac182fc-cbfd-46c4-85bb-2a546cb238e1 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:30 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.670600, lon=9.409180, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:30 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:34 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:34 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:34 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:34 [INFO] src.data.data_loader - Wetterdaten für Node TARP_E03 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:34 [INFO] src.data.data_loader - Historische Zeitreihen für TARP_E03 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/TARP_E03_hist.csv
# 2025-12-17 12:00:34 [INFO] src.data.data_loader - Verarbeite Node TARP_E01 (DP=03636523-35f2-428f-86e8-c260fafbe330) ...
# 2025-12-17 12:00:34 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für TARP_E01: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:34 [INFO] src.data.data_loader - Node TARP_E01: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:34 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=03636523-35f2-428f-86e8-c260fafbe330, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:34 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=03636523-35f2-428f-86e8-c260fafbe330 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:34 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=03636523-35f2-428f-86e8-c260fafbe330 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:34 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.670600, lon=9.409180, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:34 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:36 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:36 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:36 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:36 [INFO] src.data.data_loader - Wetterdaten für Node TARP_E01 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:36 [INFO] src.data.data_loader - Historische Zeitreihen für TARP_E01 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/TARP_E01_hist.csv
# 2025-12-17 12:00:36 [INFO] src.data.data_loader - Verarbeite Node WEDING_E14 (DP=81517d2b-2fe1-4b64-b34a-2e03048cc900) ...
# 2025-12-17 12:00:36 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für WEDING_E14: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:36 [INFO] src.data.data_loader - Node WEDING_E14: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:36 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=81517d2b-2fe1-4b64-b34a-2e03048cc900, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:36 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=81517d2b-2fe1-4b64-b34a-2e03048cc900 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:36 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=81517d2b-2fe1-4b64-b34a-2e03048cc900 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:36 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.751918, lon=9.405946, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:36 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:41 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:41 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:41 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:41 [INFO] src.data.data_loader - Wetterdaten für Node WEDING_E14 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:41 [INFO] src.data.data_loader - Historische Zeitreihen für WEDING_E14 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/WEDING_E14_hist.csv
# 2025-12-17 12:00:41 [INFO] src.data.data_loader - Verarbeite Node WEDING_E12 (DP=1635dd30-e8d5-4333-bff9-3ab20a796059) ...
# 2025-12-17 12:00:41 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für WEDING_E12: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:41 [INFO] src.data.data_loader - Node WEDING_E12: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:41 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=1635dd30-e8d5-4333-bff9-3ab20a796059, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:41 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=1635dd30-e8d5-4333-bff9-3ab20a796059 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:41 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=1635dd30-e8d5-4333-bff9-3ab20a796059 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:41 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.751918, lon=9.405946, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:41 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:42 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:42 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:43 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:43 [INFO] src.data.data_loader - Wetterdaten für Node WEDING_E12 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:43 [INFO] src.data.data_loader - Historische Zeitreihen für WEDING_E12 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/WEDING_E12_hist.csv
# 2025-12-17 12:00:43 [INFO] src.data.data_loader - Verarbeite Node SIEV_E01 (DP=563be369-1474-489b-b8ea-be4ed7e3ab5b) ...
# 2025-12-17 12:00:43 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für SIEV_E01: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:43 [INFO] src.data.data_loader - Node SIEV_E01: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:43 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=563be369-1474-489b-b8ea-be4ed7e3ab5b, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:43 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=563be369-1474-489b-b8ea-be4ed7e3ab5b -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:43 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=563be369-1474-489b-b8ea-be4ed7e3ab5b -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:43 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.652402, lon=9.438555, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:43 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:45 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:45 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:45 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:45 [INFO] src.data.data_loader - Wetterdaten für Node SIEV_E01 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:46 [INFO] src.data.data_loader - Historische Zeitreihen für SIEV_E01 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/SIEV_E01_hist.csv
# 2025-12-17 12:00:46 [INFO] src.data.data_loader - Verarbeite Node SIES_E02 (DP=3ca16fd7-6946-4dbe-b733-397e8291ff82) ...
# 2025-12-17 12:00:46 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für SIES_E02: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:46 [INFO] src.data.data_loader - Node SIES_E02: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:46 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=3ca16fd7-6946-4dbe-b733-397e8291ff82, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:46 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=3ca16fd7-6946-4dbe-b733-397e8291ff82 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:46 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=3ca16fd7-6946-4dbe-b733-397e8291ff82 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:46 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.637165, lon=9.443465, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:46 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:48 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:48 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:48 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:48 [INFO] src.data.data_loader - Wetterdaten für Node SIES_E02 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:48 [INFO] src.data.data_loader - Historische Zeitreihen für SIES_E02 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/SIES_E02_hist.csv
# 2025-12-17 12:00:48 [INFO] src.data.data_loader - Node BOLN_E02 ist ein derived node – EIOT- und Wetter-Abruf werden später aus Basis-Knoten abgeleitet.
# 2025-12-17 12:00:48 [INFO] src.data.data_loader - Verarbeite Node BOLN_E03 (DP=bf40c502-ea38-4eca-986a-11fa618c97f1) ...
# 2025-12-17 12:00:48 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für BOLN_E03: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:48 [INFO] src.data.data_loader - Node BOLN_E03: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:48 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=bf40c502-ea38-4eca-986a-11fa618c97f1, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:48 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=bf40c502-ea38-4eca-986a-11fa618c97f1 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:48 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=bf40c502-ea38-4eca-986a-11fa618c97f1 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:48 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.615976, lon=9.449164, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:48 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:50 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:50 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:50 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:50 [INFO] src.data.data_loader - Wetterdaten für Node BOLN_E03 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:50 [INFO] src.data.data_loader - Historische Zeitreihen für BOLN_E03 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/BOLN_E03_hist.csv
# 2025-12-17 12:00:50 [INFO] src.data.data_loader - Verarbeite Node BOLN_E01 (DP=34482f6c-cbbc-4f7f-99ae-db73a5885eb9) ...
# 2025-12-17 12:00:50 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für BOLN_E01: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:50 [INFO] src.data.data_loader - Node BOLN_E01: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:50 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=34482f6c-cbbc-4f7f-99ae-db73a5885eb9, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:50 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=34482f6c-cbbc-4f7f-99ae-db73a5885eb9 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:50 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=34482f6c-cbbc-4f7f-99ae-db73a5885eb9 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:50 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.615976, lon=9.449164, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:50 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:52 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:52 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:52 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:52 [INFO] src.data.data_loader - Wetterdaten für Node BOLN_E01 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:52 [INFO] src.data.data_loader - Historische Zeitreihen für BOLN_E01 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/BOLN_E01_hist.csv
# 2025-12-17 12:00:52 [INFO] src.data.data_loader - Verarbeite Node BOLS_E42 (DP=c076ad04-1a18-434d-8e86-34e081b0e4f6) ...
# 2025-12-17 12:00:52 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für BOLS_E42: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:52 [INFO] src.data.data_loader - Node BOLS_E42: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:52 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=c076ad04-1a18-434d-8e86-34e081b0e4f6, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:52 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=c076ad04-1a18-434d-8e86-34e081b0e4f6 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:52 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=c076ad04-1a18-434d-8e86-34e081b0e4f6 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:52 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.576814, lon=9.473114, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:52 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:54 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:54 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:55 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:55 [INFO] src.data.data_loader - Wetterdaten für Node BOLS_E42 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:55 [INFO] src.data.data_loader - Historische Zeitreihen für BOLS_E42 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/BOLS_E42_hist.csv
# 2025-12-17 12:00:55 [INFO] src.data.data_loader - Verarbeite Node BOLS_E41 (DP=d6c78726-ec8e-4bb4-aceb-75fb6e3f73c9) ...
# 2025-12-17 12:00:55 [INFO] src.data.data_loader - Gefundene bestehende Hist-Daten für BOLS_E41: von 2024-01-01 00:00:00 bis 2025-12-17 09:30:00 (Zeilen: 68775)
# 2025-12-17 12:00:55 [INFO] src.data.data_loader - Node BOLS_E41: vorhandene Daten bis 2025-12-17 09:30:00 (local=2025-12-17 09:30:00+01:00), lade neu ab 2025-12-17 08:45:00+00:00 (globaler Start UTC=2024-01-01 00:00:00+00:00).
# 2025-12-17 12:00:55 [INFO] src.data.eiot_client - EIOT: Hole Chunk 1 für DP=d6c78726-ec8e-4bb4-aceb-75fb6e3f73c9, 2025-12-17T08:45:00.000Z bis 2025-12-17T11:00:17.000Z
# 2025-12-17 12:00:55 [INFO] src.data.eiot_client - EIOT: Chunk 1 für DP=d6c78726-ec8e-4bb4-aceb-75fb6e3f73c9 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:55 [INFO] src.data.eiot_client - EIOT: Gesamt für DP=d6c78726-ec8e-4bb4-aceb-75fb6e3f73c9 -> 9 Samples, processedSamples=125
# 2025-12-17 12:00:55 [INFO] src.data.weather_loader - Hole Wetterdaten von Open-Meteo (lat=54.576814, lon=9.473114, start=2024-01-01 01:00:00+01:00, end=2025-12-17 12:00:17.397424+01:00, forecast_hours=24, tz=Europe/Berlin)
# 2025-12-17 12:00:55 [INFO] src.data.weather_loader - Historische Wetterdaten: 2024-01-01T00:00 bis 2025-12-17T11:00 (timezone=Europe/Berlin)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - [historisch] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Prognose-Wetterdaten: 2025-12-17T11:15 bis 2025-12-18T11:15 (expected_steps=96, timezone=Europe/Berlin)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - [forecast] 15-Minuten-Auflösung erkannt.
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Wetterdaten für Node BOLS_E41 geladen (hist=68781, forecast=96).
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Historische Zeitreihen für BOLS_E41 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/BOLS_E41_hist.csv
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Berechne derived Node JUBO_E01 via field_sum.
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Node JUBO_E01: abgeleitete P_MW-Reihe erzeugt (68780 Zeitschritte).
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Berechne derived Node BOLN_E02 via field_sum.
# 2025-12-17 12:00:57 [WARNING] src.data.data_loader - Derived-Node BOLN_E02: Basis-Node BOLN_E02 hat keine Messreihe – überspringe diesen Term.
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Node BOLN_E02: abgeleitete P_MW-Reihe erzeugt (68780 Zeitschritte).
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Node JUBO_E01: Wetter-Historie von JUBO_E03 übernommen (68781 Zeilen).
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Node JUBO_E01: Wetter-Prognose von JUBO_E03 übernommen (96 Zeilen).
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Node BOLN_E02: Wetter-Historie von BOLN_E03 übernommen (68781 Zeilen).
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Node BOLN_E02: Wetter-Prognose von BOLN_E03 übernommen (96 Zeilen).
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Historie für JUBO_E01 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/JUBO_E01_hist.csv
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Derived-Historie für BOLN_E02 gespeichert (68781 Zeilen, 4 Spalten) nach /Users/martinkrawtzow/Documents/Masterthesis/thesis/Code/Github/masterthesis/src/data/raw/timeseries/BOLN_E02_hist.csv
# 2025-12-17 12:00:57 [INFO] src.data.data_loader - Datenladen abgeschlossen.
# 2025-12-17 12:00:57 [INFO] src.main - Datenziehen (load_all_data) abgeschlossen in 40.24 s
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/SHUW_E24_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/SHUW_E23_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/JUBO_E02_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/JUBO_E03_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/TARP_E03_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/TARP_E01_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/WEDING_E14_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/WEDING_E12_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/SIEV_E01_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/SIES_E02_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/BOLN_E03_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/BOLN_E01_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/BOLS_E42_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/BOLS_E41_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/JUBO_E01_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.data.weather_loader - Wetter-Forecast gespeichert: src/data/raw/weather_forecast/BOLN_E02_weather_forecast.csv (Zeilen: 96)
# 2025-12-17 12:00:57 [INFO] src.main - Forecast-CSV Schreiben abgeschlossen in 0.01 s
# 2025-12-17 12:00:57 [INFO] src.main - Daten geladen: 16 Nodes, 16 Messreihen, 16 Wetter-Hist, 16 Wetter-Forecast.
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node SHUW_E24 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node SHUW_E23 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node JUBO_E02 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node JUBO_E03 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node TARP_E03 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node TARP_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node WEDING_E14 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node WEDING_E12 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node SIEV_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node SIES_E02 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node BOLN_E03 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node BOLN_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node BOLS_E42 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node BOLS_E41 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node JUBO_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige P_MW für Node BOLN_E02 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node SHUW_E24 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node SHUW_E23 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node JUBO_E02 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node JUBO_E03 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node TARP_E03 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node TARP_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node WEDING_E14 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node WEDING_E12 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node SIEV_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node SIES_E02 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node BOLN_E03 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node BOLN_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node BOLS_E42 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node BOLS_E41 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node JUBO_E01 ...
# 2025-12-17 12:00:57 [INFO] src.data.data_cleaning - Bereinige Wetter-Historie für Node BOLN_E02 ...
# 2025-12-17 12:00:57 [INFO] src.main - Datenbereinigung (clean_data) abgeschlossen in 0.12 s
# 2025-12-17 12:00:57 [INFO] src.main - Daten bereinigt.
# 2025-12-17 12:00:57 [INFO] src.main - Gesamtzeit bis Ende Schritt 2: 40.37 s
# 2025-12-17 12:00:57 [INFO] src.main - Stoppe nach Schritt 2 (Datenladen + Bereinigung, Testmodus).
# ---- Überblick ----
# Nodes: 16
# Beispiel-Node: SHUW_E24
# Keys im Datenobjekt: ['nodes', 'measurements', 'weather_hist', 'weather_forecast']
#
# ---- Frequenz-Analyse ----
#           node       unique_steps step_counts
# 0     SHUW_E24  [0 days 00:15:00]     [68779]
# 1     SHUW_E23  [0 days 00:15:00]     [68779]
# 2     JUBO_E02  [0 days 00:15:00]     [68779]
# 3     JUBO_E03  [0 days 00:15:00]     [68779]
# 4     TARP_E03  [0 days 00:15:00]     [68779]
# 5     TARP_E01  [0 days 00:15:00]     [68779]
# 6   WEDING_E14  [0 days 00:15:00]     [68779]
# 7   WEDING_E12  [0 days 00:15:00]     [68779]
# 8     SIEV_E01  [0 days 00:15:00]     [68779]
# 9     SIES_E02  [0 days 00:15:00]     [68779]
# 10    BOLN_E03  [0 days 00:15:00]     [68779]
# 11    BOLN_E01  [0 days 00:15:00]     [68779]
# 12    BOLS_E42  [0 days 00:15:00]     [68779]
# 13    BOLS_E41  [0 days 00:15:00]     [68779]
# 14    JUBO_E01  [0 days 00:15:00]     [68779]
# 15    BOLN_E02  [0 days 00:15:00]     [68779]
#
# ---- Gefundene Lücken ----
# Keine Lücken gefunden.
#
# ---- NaN Analyse P_MW ----
#             raw_nans  clean_nans  len_raw  len_clean
# node
# SHUW_E24        2360        2089    68780      68780
# SHUW_E23        4175        3742    68780      68780
# JUBO_E02        2137        1746    68780      68780
# JUBO_E03         487         233    68780      68780
# TARP_E03         596         203    68780      68780
# TARP_E01         559         215    68780      68780
# WEDING_E14     52749       52685    68780      68780
# WEDING_E12     52748       52685    68780      68780
# SIEV_E01        4376        4006    68780      68780
# SIES_E02        2458        2176    68780      68780
# BOLN_E03        2362        2081    68780      68780
# BOLN_E01        2348        2074    68780      68780
# BOLS_E42       52721       52671    68780      68780
# BOLS_E41       52723       52671    68780      68780
# JUBO_E01           0           0    68780      68780
# BOLN_E02           0           0    68780      68780
#
# ---- NaN Analyse Wetter ----
#             raw_nan_temperature_C  clean_nan_temperature_C  \
# node
# SHUW_E24                        0                        0
# SHUW_E23                        0                        0
# JUBO_E02                        0                        0
# JUBO_E03                        0                        0
# TARP_E03                        0                        0
# TARP_E01                        0                        0
# WEDING_E14                      0                        0
# WEDING_E12                      0                        0
# SIEV_E01                        0                        0
# SIES_E02                        0                        0
# BOLN_E03                        0                        0
# BOLN_E01                        0                        0
# BOLS_E42                        0                        0
# BOLS_E41                        0                        0
# JUBO_E01                        0                        0
# BOLN_E02                        0                        0
#
#             raw_nan_wind_speed_mps  clean_nan_wind_speed_mps  \
# node
# SHUW_E24                         0                         0
# SHUW_E23                         0                         0
# JUBO_E02                         0                         0
# JUBO_E03                         0                         0
# TARP_E03                         0                         0
# TARP_E01                         0                         0
# WEDING_E14                       0                         0
# WEDING_E12                       0                         0
# SIEV_E01                         0                         0
# SIES_E02                         0                         0
# BOLN_E03                         0                         0
# BOLN_E01                         0                         0
# BOLS_E42                         0                         0
# BOLS_E41                         0                         0
# JUBO_E01                         0                         0
# BOLN_E02                         0                         0
#
#             raw_nan_solar_radiation_Wm2  clean_nan_solar_radiation_Wm2
# node
# SHUW_E24                              0                              0
# SHUW_E23                              0                              0
# JUBO_E02                              0                              0
# JUBO_E03                              0                              0
# TARP_E03                              0                              0
# TARP_E01                              0                              0
# WEDING_E14                            0                              0
# WEDING_E12                            0                              0
# SIEV_E01                              0                              0
# SIES_E02                              0                              0
# BOLN_E03                              0                              0
# BOLN_E01                              0                              0
# BOLS_E42                              0                              0
# BOLS_E41                              0                              0
# JUBO_E01                              0                              0
# BOLN_E02                              0                              0
#
# ---- Derived Node Validierung ----
#
# ---- Basisstatistiken P_MW ----
#                    min         max       mean        std
# node
# SHUW_E24   -195.637267  142.890660 -39.384429  29.202593
# SHUW_E23   -150.303600  427.740991 -27.658203  19.193990
# JUBO_E02    -57.498167    7.473509 -13.494380  14.222357
# JUBO_E03    -40.642751   61.820920  -6.475294   6.793201
# TARP_E03    -72.506533  208.333333   3.916114  15.759556
# TARP_E01    -27.266667  171.666667  20.365731  14.714036
# WEDING_E14  -64.247700   34.173133  -0.465954  13.232770
# WEDING_E12  -66.457053   65.227807   5.642528  11.973039
# SIEV_E01    -62.488713    0.295629  -6.822334  12.789222
# SIES_E02    -12.309907    0.204346  -3.905716   3.847098
# BOLN_E03    -43.940660    0.089329 -10.323659  10.877758
# BOLN_E01    -20.360947    0.250119  -4.623506   5.277516
# BOLS_E42    -51.957700   48.057047  -0.648711  18.606287
# BOLS_E41    -52.239840   48.051307  -0.663647  18.611518
# JUBO_E01    -61.828244   85.655653  19.499525  17.869965
# BOLN_E02     -0.089329   43.940660   9.974985  10.857752
# ---- Korrelationen zwischen Wetter und P_MW ----
#                      temperature_C  wind_speed_mps  solar_radiation_Wm2  \
# temperature_C             1.000000        0.045168             0.526581
# wind_speed_mps            0.045168        1.000000             0.151188
# solar_radiation_Wm2       0.526581        0.151188             1.000000
# P_MW                     -0.042033       -0.777339            -0.144088
#
#                          P_MW
# temperature_C       -0.042033
# wind_speed_mps      -0.777339
# solar_radiation_Wm2 -0.144088
# P_MW                 1.000000
#
# ---- Sprung-Analyse P_MW (diff-basierte Jumps) ----
#              diff_std  threshold  num_big_jumps
# node
# SIEV_E01     3.174002   9.522005           1732
# SHUW_E24     7.847871  23.543612           1579
# JUBO_E03     1.546132   4.638397           1545
# BOLN_E01     1.736750   5.210251           1529
# SHUW_E23     7.933222  23.799665           1455
# SIES_E02     0.921996   2.765989           1379
# BOLN_E02     3.417279  10.251836           1313
# JUBO_E02     2.572670   7.718011           1277
# BOLN_E03     3.406301  10.218903           1267
# TARP_E01     3.889247  11.667740           1255
# JUBO_E01     3.584916  10.754749           1096
# TARP_E03     4.830487  14.491460            785
# WEDING_E12   5.233261  15.699784            193
# WEDING_E14   4.389263  13.167788            133
# BOLS_E41    11.990428  35.971284            115
# BOLS_E42    12.073873  36.221618            105
# ---- Tagesprofil (P_MW, Mittelwert je Stunde) ----
# hour
# 0    -31.990102
# 1    -31.044582
# 2    -31.269148
# 3    -33.527397
# 4    -36.547303
# 5    -38.203137
# 6    -37.825976
# 7    -38.381505
# 8    -40.931040
# 9    -44.397889
# 10   -45.647197
# 11   -45.295206
# 12   -45.779852
# 13   -47.762808
# 14   -47.811586
# 15   -46.323834
# 16   -44.122131
# 17   -42.825338
# 18   -40.969457
# 19   -38.472643
# 20   -36.044487
# 21   -33.596426
# 22   -33.347326
# 23   -33.061087
# Name: P_MW, dtype: float64
#
# ---- Wochenprofil (P_MW, Mittelwert je Wochentag; 0=Mo) ----
# weekday
# 0   -39.405957
# 1   -38.110500
# 2   -38.377306
# 3   -37.696867
# 4   -43.008406
# 5   -38.462095
# 6   -40.682048
# Name: P_MW, dtype: float64
# ---- Korrelation P_MW zwischen Nodes ----
#             SHUW_E24  SHUW_E23  JUBO_E02  JUBO_E03  TARP_E03  TARP_E01  \
# SHUW_E24    1.000000  0.807665  0.857749  0.549098 -0.457542 -0.764607
# SHUW_E23    0.807665  1.000000  0.560166  0.412291 -0.241436 -0.665599
# JUBO_E02    0.857749  0.560166  1.000000  0.384469 -0.610803 -0.599903
# JUBO_E03    0.549098  0.412291  0.384469  1.000000 -0.319327 -0.410635
# TARP_E03   -0.457542 -0.241436 -0.610803 -0.319327  1.000000  0.073603
# TARP_E01   -0.764607 -0.665599 -0.599903 -0.410635  0.073603  1.000000
# WEDING_E14  0.471522  0.198859  0.569967  0.312583 -0.998497  0.090782
# WEDING_E12  0.064581  0.047687  0.065038  0.209311 -0.719442  0.524586
# SIEV_E01    0.130874  0.169254 -0.071786  0.794855 -0.059831 -0.153684
# SIES_E02    0.749909  0.589362  0.829603  0.268144 -0.502864 -0.598801
# BOLN_E03    0.721228  0.653532  0.786750  0.222183 -0.440473 -0.562664
# BOLN_E01    0.691329  0.600840  0.780321  0.193831 -0.445549 -0.540020
# BOLS_E42   -0.317388 -0.432623  0.068329  0.227196  0.316083 -0.443514
# BOLS_E41   -0.290365 -0.473949  0.065442  0.222524  0.299053 -0.422734
# JUBO_E01   -0.877887 -0.595237 -0.932383 -0.670263  0.602759  0.628027
# BOLN_E02   -0.718267 -0.650734 -0.770202 -0.200510  0.435912  0.526046
#
#             WEDING_E14  WEDING_E12  SIEV_E01  SIES_E02  BOLN_E03  BOLN_E01  \
# SHUW_E24      0.471522    0.064581  0.130874  0.749909  0.721228  0.691329
# SHUW_E23      0.198859    0.047687  0.169254  0.589362  0.653532  0.600840
# JUBO_E02      0.569967    0.065038 -0.071786  0.829603  0.786750  0.780321
# JUBO_E03      0.312583    0.209311  0.794855  0.268144  0.222183  0.193831
# TARP_E03     -0.998497   -0.719442 -0.059831 -0.502864 -0.440473 -0.445549
# TARP_E01      0.090782    0.524586 -0.153684 -0.598801 -0.562664 -0.540020
# WEDING_E14    1.000000    0.723214  0.072521  0.500871  0.260047  0.390606
# WEDING_E12    0.723214    1.000000  0.231851  0.066221  0.100937  0.086554
# SIEV_E01      0.072521    0.231851  1.000000 -0.126835 -0.178085 -0.191904
# SIES_E02      0.500871    0.066221 -0.126835  1.000000  0.797483  0.772199
# BOLN_E03      0.260047    0.100937 -0.178085  0.797483  1.000000  0.798055
# BOLN_E01      0.390606    0.086554 -0.191904  0.772199  0.798055  1.000000
# BOLS_E42     -0.318002   -0.424938  0.251029  0.047612 -0.045430 -0.014948
# BOLS_E41     -0.300611   -0.448453  0.246622  0.046654 -0.041478 -0.013861
# JUBO_E01     -0.564596   -0.130433 -0.237009 -0.754434 -0.699934 -0.686155
# BOLN_E02     -0.256234   -0.099285  0.183895 -0.794887 -0.996922 -0.795150
#
#             BOLS_E42  BOLS_E41  JUBO_E01  BOLN_E02
# SHUW_E24   -0.317388 -0.290365 -0.877887 -0.718267
# SHUW_E23   -0.432623 -0.473949 -0.595237 -0.650734
# JUBO_E02    0.068329  0.065442 -0.932383 -0.770202
# JUBO_E03    0.227196  0.222524 -0.670263 -0.200510
# TARP_E03    0.316083  0.299053  0.602759  0.435912
# TARP_E01   -0.443514 -0.422734  0.628027  0.526046
# WEDING_E14 -0.318002 -0.300611 -0.564596 -0.256234
# WEDING_E12 -0.424938 -0.448453 -0.130433 -0.099285
# SIEV_E01    0.251029  0.246622 -0.237009  0.183895
# SIES_E02    0.047612  0.046654 -0.754434 -0.794887
# BOLN_E03   -0.045430 -0.041478 -0.699934 -0.996922
# BOLN_E01   -0.014948 -0.013861 -0.686155 -0.795150
# BOLS_E42    1.000000  0.936609 -0.140429  0.044317
# BOLS_E41    0.936609  1.000000 -0.136182  0.040064
# JUBO_E01   -0.140429 -0.136182  1.000000  0.681885
# BOLN_E02    0.044317  0.040064  0.681885  1.000000
# ---- Outlier-Analyse P_MW (z-Score) ----
#                  mean        std  num_outliers(|z|>4)  outlier_fraction
# node
# TARP_E01    20.365731  14.714036                  237          0.003446
# TARP_E03     3.916114  15.759556                  177          0.002573
# JUBO_E03    -6.475294   6.793201                  150          0.002181
# SHUW_E24   -39.384429  29.202593                   58          0.000843
# SHUW_E23   -27.658203  19.193990                   43          0.000625
# SIEV_E01    -6.822334  12.789222                   40          0.000582
# WEDING_E14  -0.465954  13.232770                   22          0.000320
# WEDING_E12   5.642528  11.973039                    9          0.000131
# JUBO_E01    19.499525  17.869965                    1          0.000015
# JUBO_E02   -13.494380  14.222357                    0          0.000000
# SIES_E02    -3.905716   3.847098                    0          0.000000
# BOLN_E03   -10.323659  10.877758                    0          0.000000
# BOLN_E01    -4.623506   5.277516                    0          0.000000
# BOLS_E42    -0.648711  18.606287                    0          0.000000
# BOLS_E41    -0.663647  18.611518                    0          0.000000
# BOLN_E02     9.974985  10.857752                    0          0.000000
# EDA erweitert um Sprünge, Tages-/Wochenprofile, Node-Korrelationen und Outlier.
#
# EDA abgeschlossen.

# %% [markdown]
# ## Graph inspection

# %%
# ============================================================
# Überblick über whole_graph.json + Kanten ohne Reaktanz
# (ohne direkte Verbindung zu einer Sammelschiene)
# ============================================================

import json
import pandas as pd
from src.config import GRAPH_PATH

try:
    from IPython.display import display
except ImportError:
    display = print

# -------------------------
# 1) JSON einlesen
# -------------------------
with open(GRAPH_PATH, "r", encoding="utf-8") as f:
    elems = json.load(f)

nodes = [e for e in elems if "data" in e and "source" not in e["data"]]
edges = [e for e in elems if "data" in e and "source" in e["data"]]

print("==== GROBER ÜBERBLICK ====")
print(f"Anzahl Knoten im JSON: {len(nodes)}")
print(f"Anzahl Kanten im JSON: {len(edges)}\n")

# -------------------------
# 2) Knotentypen auswerten
# -------------------------
node_info = []
for e in nodes:
    d = e["data"]
    node_info.append({
        "id": d["id"],
        "label": d.get("label", d["id"]),
        "type": d.get("type", None)
    })

df_nodes = pd.DataFrame(node_info)

print("Knotentypen im JSON:")
print(df_nodes["type"].value_counts())
print("\nBeispiel-Knoten:")
display(df_nodes.head(10))

# Mapping ID -> Typ
node_type_map = df_nodes.set_index("id")["type"].to_dict()

# -------------------------
# 3) Kanten grob anzeigen
# -------------------------
edge_info = []
for e in edges:
    d = e["data"]
    feats = d.get("features", {}) or {}
    edge_info.append({
        "id": d.get("id"),
        "label": d.get("label"),
        "source": d.get("source"),
        "target": d.get("target"),
        "source_type": node_type_map.get(d.get("source")),
        "target_type": node_type_map.get(d.get("target")),
        "has_X_total_ohm": feats.get("X_total_ohm") is not None,
        "has_X_ohm_per_km": feats.get("X_ohm_per_km") is not None,
        "strom_limit_a": feats.get("Strom_Limit_in_A"),
    })

df_edges = pd.DataFrame(edge_info)

print("\nBeispiel-Kanten:")
display(df_edges.head(20))

# -------------------------
# 4) Kanten ohne Reaktanz
#    UND nicht an Sammelschiene
# -------------------------

def has_reactance(row):
    return bool(row["has_X_total_ohm"] or row["has_X_ohm_per_km"])

def touches_busbar(row):
    return (row["source_type"] == "busbar") or (row["target_type"] == "busbar")

mask_no_x_and_no_bus = (~df_edges.apply(has_reactance, axis=1)) & (~df_edges.apply(touches_busbar, axis=1))

df_edges_problem = df_edges[mask_no_x_and_no_bus].copy()

print("\n==== KANTEN OHNE REAKTANZ (UND NICHT AN SAMMELSCHIENE) ====")
print(f"Anzahl solcher Kanten: {len(df_edges_problem)}")

if len(df_edges_problem) > 0:
    display(df_edges_problem[[
        "id", "label", "source", "source_type", "target", "target_type", "strom_limit_a"
    ]])
else:
    print("Keine Kanten gefunden, die die Kriterien erfüllen.")
# Out:
# ==== GROBER ÜBERBLICK ====
# Anzahl Knoten im JSON: 29
# Anzahl Kanten im JSON: 29
#
# Knotentypen im JSON:
# type
# uw_field    14
# busbar       7
# junction     6
# battery      2
# Name: count, dtype: int64
#
# Beispiel-Knoten:
#          id     label      type
# 0    WEDING    WEDING    busbar
# 1      TARP      TARP    busbar
# 2      JUBO      JUBO    busbar
# 3      SHUW      SHUW    busbar
# 4      BOLN      BOLN    busbar
# 5      SIES      SIES    busbar
# 6      SIEV      SIEV    busbar
# 7  SHUW_E24  SHUW_E24  uw_field
# 8  SHUW_E23  SHUW_E23  uw_field
# 9  JUBO_E01  JUBO_E01  uw_field
# Beispiel-Kanten:
#                                                   id  \
# 0                                        SHUW_SS_E23
# 1                                        SHUW_SS_E24
# 2                                      JUBO_E01_JUBO
# 3                                      JUBO_E02_JUBO
# 4                                      JUBO_E03_JUBO
# 5                                   TARP_SS_TARP_E01
# 6                                   TARP_SS_TARP_E03
# 7                               WEDING_SS_WEDING_E14
# 8                               WEDING_SS_WEDING_E12
# 9                                        SIEV_SS_E01
# 10                                       SIES_SS_E02
# 11                                       BOLN_SS_E02
# 12                                       BOLN_SS_E03
# 13                                       BOLN_SS_E01
# 14     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV SHUW-BOLN A3
# 15     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLS A3-BOLS
# 16  110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLS A3-BOLN A3
# 17     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLN A3-BOLN
# 18  110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLN A3-SIES A3
# 19     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV SIES A3-SIES
#
#                                                label      source    target  \
# 0                                        SHUW_SS_E23        SHUW  SHUW_E23
# 1                                        SHUW_SS_E24        SHUW  SHUW_E24
# 2                                      JUBO_E01_JUBO        JUBO  JUBO_E01
# 3                                      JUBO_E02_JUBO    JUBO_E02      JUBO
# 4                                      JUBO_E03_JUBO    JUBO_E03      JUBO
# 5                                   TARP_SS_TARP_E01    TARP_E01      TARP
# 6                                   TARP_SS_TARP_E03        TARP  TARP_E03
# 7                               WEDING_SS_WEDING_E14  WEDING_E14    WEDING
# 8                               WEDING_SS_WEDING_E12  WEDING_E12    WEDING
# 9                                        SIEV_SS_E01    SIEV_E01      SIEV
# 10                                       SIES_SS_E02    SIES_E02      SIES
# 11                                       BOLN_SS_E02    BOLN_E02      BOLN
# 12                                       BOLN_SS_E03        BOLN  BOLN_E03
# 13                                       BOLN_SS_E01        BOLN  BOLN_E01
# 14     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV SHUW-BOLN A3    SHUW_E23   BOLS_A3
# 15     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLS A3-BOLS    BOLS_E41   BOLS_A3
# 16  110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLS A3-BOLN A3     BOLS_A3   BOLN_A3
# 17     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLN A3-BOLN     BOLN_A3  BOLN_E02
# 18  110-SHUW-WEDI-ROT,BOLN,SIES,SIEV BOLN A3-SIES A3     SIES_A3   BOLN_A3
# 19     110-SHUW-WEDI-ROT,BOLN,SIES,SIEV SIES A3-SIES     SIES_A3  SIES_E02
#
#    source_type target_type  has_X_total_ohm  has_X_ohm_per_km  strom_limit_a
# 0       busbar    uw_field            False             False            NaN
# 1       busbar    uw_field            False             False            NaN
# 2       busbar    uw_field            False             False            NaN
# 3     uw_field      busbar            False             False            NaN
# 4     uw_field      busbar            False             False            NaN
# 5     uw_field      busbar            False             False            NaN
# 6       busbar    uw_field            False             False            NaN
# 7     uw_field      busbar            False             False            NaN
# 8     uw_field      busbar            False             False            NaN
# 9     uw_field      busbar            False             False            NaN
# 10    uw_field      busbar            False             False            NaN
# 11    uw_field      busbar            False             False            NaN
# 12      busbar    uw_field            False             False            NaN
# 13      busbar    uw_field            False             False            NaN
# 14    uw_field    junction             True             False          547.0
# 15     battery    junction             True             False          547.0
# 16    junction    junction             True             False          547.0
# 17    junction    uw_field             True             False          547.0
# 18    junction    junction             True             False          545.0
# 19    junction    uw_field             True             False          547.0
# ==== KANTEN OHNE REAKTANZ (UND NICHT AN SAMMELSCHIENE) ====
# Anzahl solcher Kanten: 0
# Keine Kanten gefunden, die die Kriterien erfüllen.
